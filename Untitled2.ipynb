# %%
menuMan = {}

# %%
def add_menu(dict, type):
    try:
        if type == 'breakfast':
            dict['breakfast'] = {
                'eggs': 5,
                'kibda': 10,
                'pesto': 7
            }
        elif type == 'lunch':
            dict['lunch'] = {
            }
        elif type == 'dinner':
            dict['dinner'] = {
            }
        else:
            raise Exception
        print(f"All items in {type} added")
    except Exception:
        print(f"We don't support {type} so it won't be added to the menu")

# %%
def print_menu(dict):
    for meal, items in dict.items():
        print(meal)
        for item, price in items.items():
            print('    {}: {} SAR'.format(item, price))

# %%
def check_item(dict, meal, item):
    if meal in dict:
        if item in dict[meal]:
            print(f'Yes, {item} is available in {meal}')
        else:
            print(f'No, {item} is not available in {meal}')
    else:
        print(f'No, {item} is not available in {meal}')

# %%
def totalPrice(lst) :
    totalPrice = 0 
    res = 0
    for x in lst :
        totalPrice += x
        res = (lambda totalPrice : totalPrice*0.15)(totalPrice)
        
    if totalPrice >= 400 :
        print(totalPrice+res, f' Tax {res}')
        print("Congratulations!! You've won an ice cup and a bottle of water")
    else :
        print(totalPrice+res, f' Tax {res}')
    
totalPrice(list_many)
# Out:
# 0  Tax 0

# %%
def lam(Dict1):
    lst = []
    for x, y in menu.items():
        for z in y:
            lst.extend(z)

    for x in lst :
        if type(x) == type(str()):
            print(x)
        if type(x) == type(float()) or type(x) == type(int()):
            res = (lambda x : x*0.15)(x)
            print(x+res , f'Tax {res}')
    
lam(list_many)
# Out:
# Italian Pizza
# 40.25 Tax 5.25
# 299.0 Tax 39.0
# California Pizza
# 34.5 Tax 4.5
# 276.0 Tax 36.0
# Pepperoni Lovers
# 36.8 Tax 4.8
# 207.0 Tax 27.0
# Chicken Supreme
# 39.1 Tax 5.1
# 218.5 Tax 28.5
# Big Tasty
# 28.75 Tax 3.75
# 460.0 Tax 60.0
# McRoyale
# 23.0 Tax 3.0
# 402.5 Tax 52.5
# Double Cheeseburger
# 32.2 Tax 4.2
# 517.5 Tax 67.5
# Beef Burger
# 25.3 Tax 3.3
# 425.5 Tax 55.5
# Cola
# 5.75 Tax 0.75
# 161.0 Tax 21.0
# Orange Juice
# 8.05 Tax 1.05
# 126.5 Tax 16.5
# Water
# 3.45 Tax 0.44999999999999996
# 0.0 Tax 0.0
# Coffee
# 11.5 Tax 1.5
# 5.75 Tax 0.75
# Garlic Bread
# 9.2 Tax 1.2
# 230.0 Tax 30.0
# Mozzarella Sticks
# 13.8 Tax 1.7999999999999998
# 345.0 Tax 45.0
# Chicken Wings
# 17.25 Tax 2.25
# 460.0 Tax 60.0
# Onion Rings
# 11.5 Tax 1.5
# 322.0 Tax 42.0

# %%
def lamMan(Dict1):
    print("\nYour menu")
    for meal1, items1 in Dict1.items():
        for item1, value1 in items1.items():
            if type(item1) == type(str()):
                print(item1)
            if type(value1) == type(float()) or type(value1) == type(int()):
                res1 = (lambda x1: x1 * 0.15)(value1)
                print(value1+res1, f'Tax {res1} ')
        
lamMan(menuMan)
# Out:
# Your menu

# %%
menu = {
    "pizza": [
        ["Italian Pizza", 35.0, 260],
        ["California Pizza", 30.0, 240],
        ["Pepperoni Lovers", 32.0, 180],
        ["Chicken Supreme", 34.0, 190],
    ],
    "burger": [
        ["Big Tasty", 25.0, 400],
        ["McRoyale", 20.0, 350],
        ["Double Cheeseburger", 28.0, 450],
        ["Beef Burger", 22.0, 370],
    ],
    "drinks": [
        ["Cola", 5.0, 140],
        ["Orange Juice", 7.0, 110],
        ["Water", 3.0, 0],
        ["Coffee", 10.0, 5],
    ],
    "appetizers": [
        ["Garlic Bread", 8.0, 200],
        ["Mozzarella Sticks", 12.0, 300],
        ["Chicken Wings", 15.0, 400],
        ["Onion Rings", 10.0, 280],
    ],
}

list_menu = []
list_many = []
list_calories = []




def total_calories(calories):
    total_calories = sum(calories)

    print(f"{total_calories}")


def total_items(items):
    i = 0
    for item in list_menu:
        i += 1
        print(f'{i} : ' , item)
    print(f"total meal is : {i}")

def fast_fode():
    while True:
        print(" ")
        print("1 - pizza")
        print("2 - burger")
        print("3 - drinks")
        print("4 - appetizers\n\t")
        inp = int(input("Enter the number 1 to 4:  "))

        if inp == 1:
            print(" ")
            print("1 - Italian Pizza")
            print("2 - California Pizza")
            print("3 - Pepperoni Lovers")
            print("4 - Chicken Supreme")
            piz = int(input("Enter the number 1 to 4:  "))

            if 1 <= piz <= 4:
                print(menu["pizza"][piz - 1])
                list_menu.append(menu["pizza"][piz - 1][0])
                list_many.append(menu["pizza"][piz - 1][1])
                list_calories.append(menu["pizza"][piz - 1][2])
            else:
                print("I told you to enter the number from 1 to 4 :) ")
                continue

        elif inp == 2:
            print(" ")
            print("1 - Big Tasty")
            print("2 - McRoyale")
            print("3 - Double Cheeseburger")
            print("4 - Beef Burger")
            piz = int(input("Enter the number 1 to 4:  "))

            if 1 <= piz <= 4:
                print(menu["burger"][piz - 1])
                list_menu.append(menu["burger"][piz - 1][0])
                list_many.append(menu["burger"][piz - 1][1])
                list_calories.append(menu["burger"][piz - 1][2])
            else:
                print("I told you to enter the number from 1 to 4  :) \n\n")
                continue

        elif inp == 3:
            print(" ")
            print("1 - Cola")
            print("2 - Orange Juice")
            print("3 - Water")
            print("4 - Coffee")
            piz = int(input("Enter the number 1 to 4:  "))

            if 1 <= piz <= 4:
                print(menu["drinks"][piz - 1])
                list_menu.append(menu["drinks"][piz - 1][0])
                list_many.append(menu["drinks"][piz - 1][1])
                list_calories.append(menu["drinks"][piz - 1][2])
            else:
                print("I told you to enter the number from 1 to 4  :) \n\n")
                continue

        elif inp == 4:
            print(" ")
            print("1 - Garlic Bread")
            print("2 - Mozzarella Sticks")
            print("3 - Chicken Wings")
            print("4 - Onion Rings")
            piz = int(input("Enter the number 1 to 4:\n"))

            if 1 <= piz <= 4:
                print(menu["appetizers"][piz - 1])
                list_menu.append(menu["appetizers"][piz - 1][0])
                list_many.append(menu["appetizers"][piz - 1][1])
                list_calories.append(menu["appetizers"][piz - 1][2])
            else:
                print("I told you to enter the number from 1 to 4  :) \n\n")
                continue

        else:
            print("I told you to enter the number from 1 to 4  :) \n\n")
            continue

        continue_shopping = (
            input("Do you want to add another product? \n\n Yes  No  : ")
            .strip()
            .lower()
        )

        if continue_shopping != "yes":
            break
try :
    user = int(input("Enter 1 for customer service \n Enter 2 for manager service \n"))
except :
    print("Enter number please")

else :

    if user == 1 :
        fast_fode()
        print(" ")
        print("Total Menus :\n ")
        total_items(list_menu)
        print(" ")
        print("Total Price1 :\n")
        totalPrice(list_many)
        print(" ")
        print("Total Calori : \n")
        total_calories(list_calories)

    elif user == 2 :
        add_menu(menuMan, 'breakfast')
        add_menu(menuMan, 'lunch')
        add_menu(menuMan, 'dinner')
        print_menu(menuMan)
        print(menuMan['breakfast']['eggs'])

        check_item(menuMan, 'breakfast', 'kibda')
        check_item(menuMan, 'lunch', 'pasta')
        lamMan(menuMan)

    else : 
        print("Invalied Number")
# Out:
# Enter 1 for customer service
#  Enter 2 for manager service
#  2
# All items in breakfast added
# All items in lunch added
# All items in dinner added
# breakfast
#     eggs: 5 SAR
#     kibda: 10 SAR
#     pesto: 7 SAR
# lunch
# dinner
# 5
# Yes, kibda is available in breakfast
# No, pasta is not available in lunch
#
# Your menu
# eggs
# 5.75 Tax 0.75
# kibda
# 11.5 Tax 1.5
# pesto
# 8.05 Tax 1.05
